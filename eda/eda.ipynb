# %%
! pip install pandas ydata_profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("../data/facescrub_metadata.csv")
df.tail()
# Out:
#              name  image_id  face_id  \
# 5295  Alley Mills    114647    51945
# 5296  Alley Mills    114648    51946
# 5297  Alley Mills    114649    51947
# 5298  Alley Mills    114651    51948
# 5299  Alley Mills    114653    51949
#
#                                                     url              bbox  \
# 5295  http://www.womansday.com/cm/womansday/images/U...    235,71,372,208
# 5296  http://pics.wikifeet.com/Alley-Mills-Feet-3486...  788,148,1107,467
# 5297  http://www.contactmusic.com/pics/lf/bold_and_b...    65,122,173,230
# 5298  http://3.bp.blogspot.com/-hnRMMXQtIcA/UHlTI8O5...    89,129,440,480
# 5299  http://www.contactmusic.com/pics/lf/bold_and_b...   115,112,280,277
#
#                                                  sha256
# 5295  4db83314e63867ef596ef3b6de4841cdce33cabc62e3b5...
# 5296  80376f8a3bc414a4aa850ed36ca4f9588688dc892a8e67...
# 5297  0af11cbb36f1a9d31b20be8d282ab1493a60973d28394b...
# 5298  b08ebdc5b8b033c6d778b6f16a4bd5ff2b40fe257bd9ad...
# ...

# %%
profile = ProfileReport(df, explorative=True)
profile.to_file("report.html")

# %%
df[df["image_id"]==103825]
# Out:
#                 name  image_id  face_id  \
# 2549      Simon Pegg    103825    53375
# 5056  Vanessa Marcil    103825    46985
# 5057  Vanessa Marcil    103825    46986
#
#                                                     url               bbox  \
# 2549  http://www.metro.us/wp-content/uploads/2013/08...  963,430,2114,1581
# 5056  http://xaxor.com/images/123215/vanessa_marcil_...     168,94,278,204
# 5057  http://xaxor.com/images/123215/vanessa_marcil_...    854,147,981,274
#
#                                                  sha256
# 2549  668f5d720d02c9593d830d89dbf051a8d19be05a434b5c...
# 5056  66fcd0766c85227f446fc5c8c1b646259122d551626ed9...
# 5057  66fcd0766c85227f446fc5c8c1b646259122d551626ed9...

# %%
df[df["image_id"]==1]
# Out:
#                 name  image_id  face_id  \
# 0      Aaron Eckhart         1        1
# 2650  Lexi Ainsworth         1        1
#
#                                                     url            bbox  \
# 0     http://upload.wikimedia.org/wikipedia/commons/...  53,177,418,542
# 2650  http://cdn.soaps.sheknows.com/images/news/2253...   45,50,174,179
#
#                                                  sha256
# 0     dec996994cf1eec33b53c203cff0e8f25638829fa2ad71...
# 2650  571435cb57e518ae0cc5855eb8f1bea0b89d447d8ad7f9...

# %%
filtered_df = pd.read_csv("../data/filtered_facescrub_metadata.csv")
filtered_df.tail()
# Out:
#                 name  image_id  face_id  \
# 1617  Christa Miller    114267    51717
# 1618  Christa Miller    114269    51719
# 1619  Christa Miller    114274    51722
# 1620     Alley Mills    114648    51946
# 1621     Alley Mills    114651    51948
#
#                                                     url               bbox  \
# 1617  http://images.fanpop.com/images/image_uploads/...   667,337,1013,683
# 1618  http://images2.fanpop.com/images/photos/670000...    513,153,845,485
# 1619  http://images4.fanpop.com/image/photos/2000000...  352,413,1037,1098
# 1620  http://pics.wikifeet.com/Alley-Mills-Feet-3486...   788,148,1107,467
# 1621  http://3.bp.blogspot.com/-hnRMMXQtIcA/UHlTI8O5...     89,129,440,480
#
#                                                  sha256
# 1617  b7e83f2cb02bce2a49cc0ee4dc59656ef9bcd19587740d...
# 1618  a64928a230d741cbabf601c404e87019f50351232bc04b...
# 1619  9e53b25e921dc8ccf9f2e27a1666ce0469042a35dabb8e...
# ...

# %%
profile = ProfileReport(filtered_df, explorative=True)
profile.to_file("filtered_report.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 254.34it/s]

# %%
filtered_df[filtered_df["image_id"]==6]
# Out:
#                name  image_id  face_id  \
# 0     Aaron Eckhart         6        6
# 820  Lexi Ainsworth         6        5
#
#                                                    url             bbox  \
# 0    http://media.zenfs.com/en_us/Movies/PhotoG/2nd...  235,158,540,463
# 820  http://www.howmuchdotheyweigh.com/wp-content/u...   101,33,211,143
#
#                                                 sha256
# 0    121e8bea5caae215b537dc116534bbd2fa7a9a60c19107...
# 820  ce1602dd83d97caa7ccdd62b6e361f8aa88e1a797e7f22...
